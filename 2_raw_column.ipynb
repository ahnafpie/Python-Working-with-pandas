# %%
# add row header

import pandas
fhand = pandas.read_csv('10.2 supermarkets-commas.txt.txt', header= None)
fhand
# Out:
#    0                1              2                 3    4            5   6
# 0  1     3666 21st St  San Francisco          CA 94114  USA      Madeira   8
# 1  2   735 Dolores St  San Francisco          CA 94119  USA  Bready Shop  15
# 2  3      332 Hill St  San Francisco  California 94114  USA  Super River  25
# 3  4     3995 23rd St  San Francisco          CA 94114  USA    Bens Shop  10
# 4  5  1056 Sanchez St  San Francisco        California  USA      Sanchez  12
# 5  6  551 Alvarado St  San Francisco          CA 94114  USA   Richvalley  20

# %%
# add column with names

import pandas
fhand = pandas.read_csv('10.2 supermarkets-commas.txt.txt', header= None)
fhand.columns = ['ID', 'Address', 'City', 'ZIP', 'Country', 'Name', 'Employees No']
fhand
# Out:
#    ID          Address           City               ZIP Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Bens Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees No
# 0             8
# 1            15
# 2            25
# 3            10
# 4            12
# 5            20

# %%
# there is a default index of 0-5 by pandas. we can drop it in several ways. let's do....
# at first we can set the index as a column name

fhand.set_index('ID')
# Out:
#             Address           City               ZIP Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA    Bens Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees No
# ID
# 1              8
# 2             15
# 3             25
# 4             10
# 5             12
# 6             20

# %%
# now if we print fhand
fhand
# Out:
#             Address           City               ZIP Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA    Bens Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees No
# ID
# 1              8
# 2             15
# 3             25
# 4             10
# 5             12
# 6             20

# %%
# # we found that the default index appeared again. to rid of this index we have to assign to a new variable

# fhand1 = fhand.set_index('ID')
fhand1
# Out:
#             Address           City               ZIP Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA    Bens Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees No
# ID
# 1              8
# 2             15
# 3             25
# 4             10
# 5             12
# 6             20

# %%
# Let's do it in a other way!

import pandas
df1 = pandas.read_csv('10.2 supermarkets-commas.txt.txt', header= None)
df1.columns = ['ID', 'Address', 'City', 'ZIP', 'Country', 'Name', 'Employees No']
df1
# Out:
#    ID          Address           City               ZIP Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Bens Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees No
# 0             8
# 1            15
# 2            25
# 3            10
# 4            12
# 5            20

# %%
df1.set_index('ID', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-47-0337f43627ba> in <module>
# ----> 1 df1.set_index('ID', inplace=True)
#
# c:\users\ahnaf\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4301
#    4302         if missing:
# -> 4303             raise KeyError(f"None of {missing} are in the columns")
#    4304
#    4305         if inplace:
#
# KeyError: "None of ['ID'] are in the columns"

# %%
# it's quite similar but with using inplace parameter you don't have assign in a new value
#let's make the differences visible, by setting address as index

df1
# Out:
#             Address           City               ZIP Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA    Bens Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees No
# ID
# 1              8
# 2             15
# 3             25
# 4             10
# 5             12
# 6             20

# %%
df1.set_index('Address')
# Out:
#                           City               ZIP Country         Name  \
# Address
# 3666 21st St     San Francisco          CA 94114     USA      Madeira
# 735 Dolores St   San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St      San Francisco  California 94114     USA  Super River
# 3995 23rd St     San Francisco          CA 94114     USA    Bens Shop
# 1056 Sanchez St  San Francisco        California     USA      Sanchez
# 551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#                  Employees No
# Address
# 3666 21st St                8
# 735 Dolores St             15
# 332 Hill St                25
# 3995 23rd St               10
# 1056 Sanchez St            12
# 551 Alvarado St            20

# %%
# let's print df1 again

df1
# Out:
#             Address           City               ZIP Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA    Bens Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees No
# ID
# 1              8
# 2             15
# 3             25
# 4             10
# 5             12
# 6             20

# %%
# it has the id again. now we want address as index and don't want to remove it from as being a column

df1.set_index('Address', inplace=True, drop=False)

# %%
#let's print now. now we have the address as as index and also have column
df1
# Out:
#                          Address           City               ZIP Country  \
# Address
# 3666 21st St        3666 21st St  San Francisco          CA 94114     USA
# 735 Dolores St    735 Dolores St  San Francisco          CA 94119     USA
# 332 Hill St          332 Hill St  San Francisco  California 94114     USA
# 3995 23rd St        3995 23rd St  San Francisco          CA 94114     USA
# 1056 Sanchez St  1056 Sanchez St  San Francisco        California     USA
# 551 Alvarado St  551 Alvarado St  San Francisco          CA 94114     USA
#
#                         Name  Employees No
# Address
# 3666 21st St         Madeira             8
# 735 Dolores St   Bready Shop            15
# 332 Hill St      Super River            25
# 3995 23rd St       Bens Shop            10
# 1056 Sanchez St      Sanchez            12
# 551 Alvarado St   Richvalley            20
